# %%
feature_number = 20
test_size = 0.3
y_feature = 'Class'

# %%
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(f'../../data/credit/{feature_number}F/data.csv')
X = data.drop(columns=y_feature,axis=1)
y = data[y_feature]
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V12       V13       V14       V15  \
# 0  0.098698  0.363787  0.090794  ... -0.617801 -0.991390 -0.311169  1.468177
# 1  0.085102 -0.255425 -0.166974  ...  1.065235  0.489095 -0.143772  0.635558
# 2  0.247676 -1.514654  0.207643  ...  0.066084  0.717293 -0.165946  2.345865
# 3  0.377436 -1.387024 -0.054952  ...  0.178228  0.507757 -0.287924 -0.631418
# 4 -0.270533  0.817739  0.753074  ...  0.538196  1.345852 -1.119670  0.175121
#
#         V16       V17       V18       V19       V20  Class
# 0 -0.470401  0.207971  0.025791  0.403993  0.251412      0
# 1  0.463917 -0.114805 -0.183361 -0.145783 -0.069083      0
# 2 -2.890083  1.109969 -0.121359 -2.261857  0.524980      0
# 3 -1.059647 -0.684093  1.965775 -1.232622 -0.208038      0
# 4 -0.451449 -0.237033 -0.038195  0.803487  0.408542      0
#
# [5 rows x 21 columns]

# %%
X
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 0       0.239599  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390
# 1      -0.078803  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095
# 2       0.791461  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293
# 3       0.237609  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757
# 4       0.592941 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941 -0.689256
# 284803  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802  1.214756
# 284804 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119 -0.183699
# 284805 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886 -1.042082
# 284806  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513 -0.188093
#
#              V14       V15       V16       V17       V18       V19       V20
# 0      -0.311169  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412
# 1      -0.143772  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083
# 2      -0.165946  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980
# 3      -0.287924 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038
# 4      -1.119670  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920  1.475829
# 284803 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556  0.059616
# 284804 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252  0.001396
# 284805  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849  0.127434
# 284806 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117  0.382948
#
# [284807 rows x 20 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(X)

# %%
df_feat = pd.DataFrame(scaled_features,columns=X.columns)
df_feat.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068  0.193679
# 1  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820 -0.063700
# 2 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454  0.639776
# 3 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150  0.192071
# 4 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999  0.479302
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.082637  0.331128  0.083386 -0.540407 -0.618296 -0.996099 -0.324610
# 1  0.071253 -0.232494 -0.153350  1.580003  1.066089  0.491418 -0.149982
# 2  0.207373 -1.378675  0.190700  0.611830  0.066137  0.720700 -0.173114
# 3  0.316018 -1.262503 -0.050468 -0.221892  0.178371  0.510169 -0.300360
# 4 -0.226510  0.744326  0.691625 -0.806147  0.538627  1.352244 -1.168034
#
#         V15       V16       V17       V18       V19       V20
# 0  1.604014 -0.536833  0.244863  0.030770  0.496282  0.326118
# 1  0.694360  0.529434 -0.135170 -0.218763 -0.179086 -0.089611
# 2  2.562906 -3.298235  1.306868 -0.144790 -2.778561  0.680975
# 3 -0.689837 -1.209296 -0.805445  2.345305 -1.514205 -0.269855
# 4  0.191323 -0.515205 -0.279081 -0.045569  0.987037  0.529939

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features,y,
                                                    test_size=test_size)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
start_time = time.time()
knn.fit(X_train,y_train)
elapsed_time = time.time() - start_time
print(f'Time spent to fit: {elapsed_time}' )
# Out:
# Time spent to fit: 0.015307903289794922

# %%
start_time = time.time()
y_pred = knn.predict(X_test)
elapsed_time = time.time() - start_time
elapsed_time
print(f'Time spent to predict: {elapsed_time}' )
# Out:
# Time spent to predict: 22.389156341552734

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[85281    20]
#  [   33   109]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85301
#            1       0.84      0.77      0.80       142
#
#     accuracy                           1.00     85443
#    macro avg       0.92      0.88      0.90     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
start_time = time.time()
score = knn.score(X_test, y_test)
elapsed_time = time.time() - start_time
print(f'score : {score} \ntime to score: {elapsed_time}' )
# Out:
# score : 0.9993797034280163
# time to score: 26.807387828826904

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 0.0006202965719836616
# MSE: 0.0006202965719836616
# RMSE: 0.024905753792721506
